# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/pinki/OneDrive/Desktop/Data_science(infosis)/Data/Data/HR_Dataset Refresh.csv')
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi  Wilson  K  10026          0                0         1
# 1  Ait Sidi  Karthikeyan     10084          1                1         1
# 2         Akinkuolie  Sarah  10196          1                1         0
# 3              Alagbe Trina  10088          1                1         0
# 4          Anderson  Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# Formate_of_naming
# Last_name/First_Name/Middle_Name

# %%
df['Employee_Name']
# Out:
# 0           Adinolfi  Wilson  K
# 1      Ait Sidi  Karthikeyan
# 2             Akinkuolie  Sarah
# 3                  Alagbe Trina
# 4              Anderson  Carol
#                  ...
# 577            Anderson  Carol
# 578           Anderson  Linda
# 579             Andreola  Colby
# 580                 Athwal  Sam
# 581            Bachiochi  Linda
# Name: Employee_Name, Length: 582, dtype: str

# %% [markdown]
# # split function

# %%
# split employee name to first_name ,middle_name and last_name   
#split(find,n = index,expand = True)
#df[['First_Name','middle_Name','Last_Name']] = df['Employee_Name'].str.split(' ',n = 2,expand = True)

# %%
#df= df.drop('Last_Name',axis = 1)

# %%
first_last  = df['Employee_Name'].str.split(' ', n=1, expand=True)
first_last
# Out:
#               0                     1
# 0      Adinolfi             Wilson  K
# 1           Ait  Sidi  Karthikeyan
# 2    Akinkuolie                 Sarah
# 3        Alagbe                 Trina
# 4      Anderson                Carol
# ..          ...                   ...
# 577    Anderson                Carol
# 578    Anderson               Linda
# 579    Andreola                 Colby
# 580      Athwal                   Sam
# 581   Bachiochi                 Linda
#
# [582 rows x 2 columns]

# %%
middle_first = first_last[1].str.strip().str.split(' ',n= 1,expand = True)
middle_first
# Out:
#           0             1
# 0    Wilson             K
# 1      Sidi   Karthikeyan
# 2     Sarah           NaN
# 3     Trina           NaN
# 4     Carol           NaN
# ..      ...           ...
# 577   Carol           NaN
# 578   Linda           NaN
# 579   Colby           NaN
# 580     Sam           NaN
# 581   Linda           NaN
#
# [582 rows x 2 columns]

# %%
# first_last[0] = Last_Name
# middle_first[0]= First_Name
# middle_first[1] = middle_name

# %%
middle_first
df['F_Name'] = middle_first[0]
df['M_Name'] = middle_first[1]
df['L_Name'] = first_last[0]

# %%
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi  Wilson  K  10026          0                0         1
# 1    Ait Sidi  Karthikeyan     10084          1                1         1
# 2           Akinkuolie  Sarah  10196          1                1         0
# 3                Alagbe Trina  10088          1                1         0
# 4            Anderson  Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 577          Anderson  Carol   10069          0                2         0
# 578         Anderson  Linda    10002          0                0         0
# 579           Andreola  Colby  10194          0                0         0
# 580               Athwal  Sam  10062          0                4         1
# 581          Bachiochi  Linda  10114          0                0         0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               582 non-null    str
#  1   EmpID                       582 non-null    int64
#  2   MarriedID                   582 non-null    int64
#  3   MaritalStatusID             582 non-null    int64
#  4   GenderID                    582 non-null    int64
#  5   EmpStatusID                 582 non-null    int64
#  6   DeptID                      582 non-null    int64
#  7   PerfScoreID                 582 non-null    int64
#  8   FromDiversityJobFairID      582 non-null    int64
#  9   Salary                      582 non-null    int64
#  10  Termd                       582 non-null    int64
#  11  PositionID                  582 non-null    int64
#  12  Position                    582 non-null    str
# ...

# %%
# python -> string
# numpy -> <U7
# pandas -> object
# date, time -> datetime
# datetime datatype -> pandas

# %%
'''
Date
-----------------------
format
--------
'%d.%m.%y' -> default
'%d-%m-%y'
mixed

dayfirst=False -> default
dayfirst=True
---------------------
After convert -> Year-Month-Day

Time
----------
---- Hour Minute Second
'%H.%M.%S' -> default
'%H-%M-%S'
mixed

After convert -> Today date Hour:Minute:Second
'''
# Out:
# "\nDate\n-----------------------\nformat\n--------\n'%d.%m.%y' -> default\n'%d-%m-%y'\nmixed\n\ndayfirst=False -> default\ndayfirst=True\n---------------------\nAfter convert -> Year-Month-Day\n\nTime\n----------\n---- Hour Minute Second\n'%H.%M.%S' -> default\n'%H-%M-%S'\nmixed\n\nAfter convert -> Today date Hour:Minute:Second\n"

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Gender', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences', 'F_Name', 'M_Name', 'L_Name'],
#       dtype='str')

# %%
# to convert into date time -> to_datetime(date_column)
df['DOB'] = pd.to_datetime(df['DOB'], format='mixed')

# %%
df['DateofHire'] = pd.to_datetime(df['DateofHire'])

# %%
df['DateofTermination'] = pd.to_datetime(df['DateofTermination'])
# generally we can not fill with any value in dateoftermination ,Keep it as NaN (BEST option)-because
# ❌ Don’t use mode
# ✅ Keep NaN OR create status column
# ✅ Treat it as event-based

# %%
df['DateofTermination']
# Out:
# 0            NaT
# 1     2016-06-16
# 2     2012-09-24
# 3            NaT
# 4     2016-09-06
#          ...
# 577   2016-09-06
# 578          NaT
# 579          NaT
# 580          NaT
# 581          NaT
# Name: DateofTermination, Length: 582, dtype: datetime64[us]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               582 non-null    str
#  1   EmpID                       582 non-null    int64
#  2   MarriedID                   582 non-null    int64
#  3   MaritalStatusID             582 non-null    int64
#  4   GenderID                    582 non-null    int64
#  5   EmpStatusID                 582 non-null    int64
#  6   DeptID                      582 non-null    int64
#  7   PerfScoreID                 582 non-null    int64
#  8   FromDiversityJobFairID      582 non-null    int64
#  9   Salary                      582 non-null    int64
#  10  Termd                       582 non-null    int64
#  11  PositionID                  582 non-null    int64
#  12  Position                    582 non-null    str
# ...

# %%
# Date of Termination -> Null
# After convert to date time -> NaT
# Do we need to clean it?

# %%
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi  Wilson  K  10026          0                0         1
# 1    Ait Sidi  Karthikeyan     10084          1                1         1
# 2           Akinkuolie  Sarah  10196          1                1         0
# 3                Alagbe Trina  10088          1                1         0
# 4            Anderson  Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 577          Anderson  Carol   10069          0                2         0
# 578         Anderson  Linda    10002          0                0         0
# 579           Andreola  Colby  10194          0                0         0
# 580               Athwal  Sam  10062          0                4         1
# 581          Bachiochi  Linda  10114          0                0         0
#
# ...

# %%
df.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Gender                          0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             386
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
df.to_csv('cleaned_hr_data',index=False)

# %%
data =pd.read_csv('C:/Users/pinki/OneDrive/Desktop/Data_science(infosis)/datascience_steps_daywise/cleaned_hr_data')

# %%
# explain

# %% [markdown]
# # Just For practice

# %%
# import pandas as pd

# df = pd.DataFrame({
#     'age': [18, 25, 35, 45, 60]
# })

# %%
'''# Normalization (Min-Max Scaling)MinMaxScaller
# It is a tool that scales values between 0 and 1
# 4. fit_transform()

# This does TWO things at once:

#  5.(a) fit()
# Learns from data
# Finds min and max values 
# 🔸 (b) transform()
Applies formula:

new value = x−min/Min-Max
# '''


# from sklearn.preprocessing import MinMaxScaler
# scaler = MinMaxScaler()
# df['age_normalized'] = scaler.fit_transform(df[['age']])

# print(df)
# Out:
# '# Normalization (Min-Max Scaling)MinMaxScaller\n# It is a tool that scales values between 0 and 1\n# 4. fit_transform()\n\n# This does TWO things at once:\n\n#  5.(a) fit()\n# Learns from data\n# Finds min and max values \n# 🔸 (b) transform()\nApplies formula:\n\nnew value = x−min/Min-Max\n# '

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Gender', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences', 'F_Name', 'M_Name', 'L_Name'],
#       dtype='str')

# %%
df['Hire_Year'] = df['DateofHire'].dt.year

# %%
df['Hire_month'] = df['DateofHire'].dt.month

# %%
df['Hire_day'] = df['DateofHire'].dt.day

# %%
# exttract name of month abd day
df['Hire_month name'] = df['DateofHire'].dt.month_name()
df['Hire_day_name'] = df['DateofHire'].dt.day_name()

# %%
df.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Gender                          0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             386
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
'''mobile  phones

mobile : 0
mobile :1
mobile : 3



'''
df['']

# %%
df['HispanicLatino'].unique()
# Out:
# <StringArray>
# ['No', 'Yes', 'no', 'yes']
# Length: 4, dtype: str

# %%
hismap = {
    'no':'No',
    'yes':'Yes',
    'Yes':'Yes',
    'No':'No'
}

df['HispanicLatino'] = df['HispanicLatino'].map(hismap)

# %%
df['HispanicLatino'].unique()
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
hismap_id = {
    'No':0,
    'Yes':1
}
df['HispanicLatino']
df['HispanicLatino'] = df['HispanicLatino'].map(hismap_id)

# %%
df['HispanicLatino'].unique()
# Out:
# array([0, 1])

# %%
df['EmploymentStatus'].unique()
# Out:
# <StringArray>
# ['Active', 'Voluntarily Terminated', 'Terminated for Cause']
# Length: 3, dtype: str

# %%
emp_status ={
    'Active':0,
    'Voluntarily Terminated':1,
    'Terminated for Cause':2
}
df['empStatus_ID'] = df['EmploymentStatus'].map(emp_status)

# %%
df['empStatus_ID'].unique()
# Out:
# array([0, 1, 2])

# %%
df.to_csv('cleaned_data1',index = False)
