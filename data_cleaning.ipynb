# %%
import pandas as pd

# %% [markdown]
# # dataset df

# %%
df = pd.read_csv('C:/Users/pinki/OneDrive/Desktop/Data_science(infosis)/Data/Data/Employees.csv')
df
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER   HIRE_DATE  \
# 0            100     Steven      King     SKING  515.123.4567  2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567  2006-01-03
# 4            104      Bruce     Ernst    BERNST  590.423.4568  2007-05-21
# ..           ...        ...       ...       ...           ...         ...
# 106          206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
# 107          203      Susan    Mavris   SMAVRIS  515.123.7777  2002-06-07
# 108          204    Hermann      Baer     HBAER  515.123.8888  2002-06-07
# 109          205    Shelley   Higgins  SHIGGINS  515.123.8080  2002-06-07
# 110          206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
#
#          JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(78)

# %%
val_mean = int(df['MANAGER_ID'].mean())
print(val_mean)
# Out:
# 124

# %%
#df['MANAGER_ID'].fillna(val_mean,inplace=True)

#df['MANAGER_ID'].fillna(val_mean, inplace=True)

# %%
df
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER   HIRE_DATE  \
# 0            100     Steven      King     SKING  515.123.4567  2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567  2006-01-03
# 4            104      Bruce     Ernst    BERNST  590.423.4568  2007-05-21
# ..           ...        ...       ...       ...           ...         ...
# 106          206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
# 107          203      Susan    Mavris   SMAVRIS  515.123.7777  2002-06-07
# 108          204    Hermann      Baer     HBAER  515.123.8888  2002-06-07
# 109          205    Shelley   Higgins  SHIGGINS  515.123.8080  2002-06-07
# 110          206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
#
#          JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# ...

# %%
# by default this  function remove all those row  which contain NaN
#df.dropna() #dropna =(axix= 0,how = 'any',inplace =false)->default'''

# %%
# This line of code remove all column which has NaN value
#df.dropna(axis =1,how = 'any',inplace = True)

# %%
# using drop 
#dropna()-> if need to change data pemanently change  inplace =  TRUE
df
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER   HIRE_DATE  \
# 0            100     Steven      King     SKING  515.123.4567  2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568  2005-09-21
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569  2001-01-13
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567  2006-01-03
# 4            104      Bruce     Ernst    BERNST  590.423.4568  2007-05-21
# ..           ...        ...       ...       ...           ...         ...
# 106          206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
# 107          203      Susan    Mavris   SMAVRIS  515.123.7777  2002-06-07
# 108          204    Hermann      Baer     HBAER  515.123.8888  2002-06-07
# 109          205    Shelley   Higgins  SHIGGINS  515.123.8080  2002-06-07
# 110          206    William     Gietz    WGIETZ  515.123.8181  2002-06-07
#
#          JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# ...

# %%
'''axies => 0(row) and a(column)
how -> any/all
dropna =(axix= 0,how = 'any',inplace =false)->default'''
# Out:
# "axies => 0(row) and a(column)\nhow -> any/all\ndropna =(axix= 0,how = 'any',inplace =false)->default"

# %%
#df.dropna(axis = 1,how ='any',inplace= True)

# %%
# column remove garnu milxa
# row ni drop garnu milxa ki nae

# %%
# any -->it delect row /column if any one value is nana
# all-->it remove only those column or row which has all value nan

# %%
'''
numeric->mean median

'''
# Out:
# '\nnumeric->mean median\n\n'

# %%
#commision_ID -> mean median
#manager_id,deparment_id ->mode
commi_mean = df['COMMISSION_PCT'].mean()
[commi_mean ]
# Out:
# [np.float64(0.22285714285714284)]

# %%
round_comm = round(commi_mean,2)# integer /float
round_comm
# Out:
# np.float64(0.22)

# %%
# format to string
fmt_mean = f'{commi_mean:.2f}' 
fmt_mean
# Out:
# '0.22'

# %%
# filna(Inplace=  true)
df['COMMISSION_PCT'] = df['COMMISSION_PCT'].fillna(round_comm)

# %%
df['COMMISSION_PCT'].unique()
# Out:
# array([0.22, 0.4 , 0.3 , 0.2 , 0.25, 0.15, 0.35, 0.1 ])

# %%
df['MANAGER_ID'].unique()
# Out:
# array([ nan, 100., 102., 103., 101., 108., 114., 120., 121., 122., 123.,
#        124., 145., 146., 147., 148., 149., 201., 205.])

# %%
mang_mode = df['MANAGER_ID'].mode()
mang_mode
# Out:
# 0    100.0
# Name: MANAGER_ID, dtype: float64

# %%
dep_mode = df['DEPARTMENT_ID'].mode()[0]
dep_mode
# Out:
# np.float64(50.0)

# %%
df['DEPARTMENT_ID']= df['DEPARTMENT_ID'].fillna(dep_mode)

# %%
df['MANAGER_ID']= df['MANAGER_ID'].fillna(mang_mode)

# %%
df.isnull().sum()
# Out:
# EMPLOYEE_ID       0
# FIRST_NAME        0
# LAST_NAME         0
# EMAIL             0
# PHONE_NUMBER      0
# HIRE_DATE         0
# JOB_ID            0
# SALARY            0
# COMMISSION_PCT    0
# MANAGER_ID        0
# DEPARTMENT_ID     0
# dtype: int64

# %%
# remove the dot from phone number
df['PHONE_NUMBER']= df['PHONE_NUMBER'].str.replace('.','', regex = False)
df
# Out:
#      EMPLOYEE_ID FIRST_NAME LAST_NAME     EMAIL PHONE_NUMBER   HIRE_DATE  \
# 0            100     Steven      King     SKING   5151234567  2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR   5151234568  2005-09-21
# 2            102        Lex   De Haan   LDEHAAN   5151234569  2001-01-13
# 3            103  Alexander    Hunold   AHUNOLD   5904234567  2006-01-03
# 4            104      Bruce     Ernst    BERNST   5904234568  2007-05-21
# ..           ...        ...       ...       ...          ...         ...
# 106          206    William     Gietz    WGIETZ   5151238181  2002-06-07
# 107          203      Susan    Mavris   SMAVRIS   5151237777  2002-06-07
# 108          204    Hermann      Baer     HBAER   5151238888  2002-06-07
# 109          205    Shelley   Higgins  SHIGGINS   5151238080  2002-06-07
# 110          206    William     Gietz    WGIETZ   5151238181  2002-06-07
#
#          JOB_ID  SALARY  COMMISSION_PCT  MANAGER_ID  DEPARTMENT_ID
# ...

# %% [markdown]
# ## Data cleaning  perform on DF2

# %%
df2 = pd.read_csv("C:/Users/pinki/OneDrive/Desktop/Data_science(infosis)/Data/Data/Fraud Detection Dataset.csv")
df2
# Out:
#       Transaction_ID  User_ID  Transaction_Amount Transaction_Type  \
# 0                 T1     4174             1292.76   ATM Withdrawal
# 1                 T2     4507             1554.58   ATM Withdrawal
# 2                 T3     1860             2395.02   ATM Withdrawal
# 3                 T4     2294              100.10     Bill Payment
# 4                 T5     2130             1490.50      POS Payment
# ...              ...      ...                 ...              ...
# 50995         T33982     2339             3112.51     Bill Payment
# 50996         T31261     2152             2897.15  Online Purchase
# 50997         T12293     3345             2204.43      POS Payment
# 50998         T42287     1518             4787.17      POS Payment
# 50999         T13665     2315              814.72      POS Payment
#
#        Time_of_Transaction Device_Used       Location  \
# 0                     16.0      Tablet  San Francisco
# ...

# %%
df2.isnull().sum()
# Out:
# Transaction_ID                         0
# User_ID                                0
# Transaction_Amount                  2520
# Transaction_Type                       0
# Time_of_Transaction                 2552
# Device_Used                         2473
# Location                            2547
# Previous_Fraudulent_Transactions       0
# Account_Age                            0
# Number_of_Transactions_Last_24H        0
# Payment_Method                      2469
# Fraudulent                             0
# dtype: int64

# %%
df2['Transaction_Amount'].count()
# Out:
# np.int64(48480)

# %%
df2['Transaction_Amount'].mean()
# df2['Transaction_Amount'].median()
# Out:
# np.float64(2996.249784447195)

# %%
x= df2['Transaction_Amount'].median()

# %%
df2['Transaction_Amount']= df2['Transaction_Amount'].fillna(x)

# %%
df2['Device_Used'].unique()
# Out:
# <StringArray>
# ['Tablet', 'Mobile', 'Desktop', nan, 'Unknown Device']
# Length: 5, dtype: str

# %%
dx = df2['Device_Used'].mode()
dx
# Out:
# 0    Desktop
# Name: Device_Used, dtype: str

# %%
df2['Device_Used']=df2['Device_Used'].fillna('Unknown Device')

# %%
df2.isnull().sum()
# Out:
# Transaction_ID                         0
# User_ID                                0
# Transaction_Amount                     0
# Transaction_Type                       0
# Time_of_Transaction                 2552
# Device_Used                            0
# Location                            2547
# Previous_Fraudulent_Transactions       0
# Account_Age                            0
# Number_of_Transactions_Last_24H        0
# Payment_Method                      2469
# Fraudulent                             0
# dtype: int64

# %%
df2['Time_of_Transaction'].unique()
# Out:
# array([16., 13., nan, 15., 19.,  2.,  3., 20.,  0., 12., 21., 14.,  7.,
#         4., 17., 10.,  5.,  8., 11., 18.,  1., 22.,  9.,  6., 23.])

# %%
tx = df2['Time_of_Transaction'].unique()
tx
# Out:
# array([16., 13., nan, 15., 19.,  2.,  3., 20.,  0., 12., 21., 14.,  7.,
#         4., 17., 10.,  5.,  8., 11., 18.,  1., 22.,  9.,  6., 23.])

# %%
df2['Time_of_Transaction']=df2['Time_of_Transaction'].fillna('0')

# %%
df2['Location'].unique()
# Out:
# <StringArray>
# ['San Francisco',      'New York',             nan,       'Chicago',
#         'Boston',       'Houston',         'Miami',   'Los Angeles',
#        'Seattle']
# Length: 9, dtype: str

# %%
ld = df2['Location'].mode()
ld
# Out:
# 0    Boston
# Name: Location, dtype: str

# %%
df2['Location'] = df2['Location'].fillna('Boston')
df2['Location']
# Out:
# 0        San Francisco
# 1             New York
# 2               Boston
# 3              Chicago
# 4        San Francisco
#              ...
# 50995         New York
# 50996            Miami
# 50997    San Francisco
# 50998         New York
# 50999      Los Angeles
# Name: Location, Length: 51000, dtype: str

# %%
df2.isnull().sum()
# Out:
# Transaction_ID                         0
# User_ID                                0
# Transaction_Amount                     0
# Transaction_Type                       0
# Time_of_Transaction                    0
# Device_Used                            0
# Location                               0
# Previous_Fraudulent_Transactions       0
# Account_Age                            0
# Number_of_Transactions_Last_24H        0
# Payment_Method                      2469
# Fraudulent                             0
# dtype: int64

# %% [markdown]
# ## In df2  all null value is removed

# %%
df2['Payment_Method'].unique()
# Out:
# <StringArray>
# ['Debit Card', 'Credit Card', nan, 'UPI', 'Net Banking', 'Invalid Method']
# Length: 6, dtype: str

# %%
pay_mod = df2['Payment_Method'].mode()
pay_mod
# Out:
# 0    UPI
# Name: Payment_Method, dtype: str

# %%
df2['Payment_Method'] = df2['Payment_Method'].fillna('Invalid Method')

# %%
df2.isnull().sum()
# Out:
# Transaction_ID                      0
# User_ID                             0
# Transaction_Amount                  0
# Transaction_Type                    0
# Time_of_Transaction                 0
# Device_Used                         0
# Location                            0
# Previous_Fraudulent_Transactions    0
# Account_Age                         0
# Number_of_Transactions_Last_24H     0
# Payment_Method                      0
# Fraudulent                          0
# dtype: int64

# %%
'''
df and df2 in both dataset null value is totally removed 
'''
# Out:
# '\ndf and df2 in both dataset null value is totally removed \n'

# %% [markdown]
# ## day6 --

# %%
# remove unwanted character
#@$%$#@@ -->regx(regular expression)

# %% [markdown]
# ## day6
# # remove unwanted  character
# # @$%$#@@ -->regx(regular expression)

# %%
df3 = pd.read_csv("C:/Users/pinki/OneDrive/Desktop/Data_science(infosis)/Data/Data/HR_Dataset Refresh.csv")
df3.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Gender', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='str')

# %%
#using map function for formatting the salary column
df3['Salary'] = df3['Salary'].map('rs.{:,.2f}'.format)

# %%
df3
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi  Wilson  K  10026          0                0         1
# 1    Ait Sidi  Karthikeyan     10084          1                1         1
# 2           Akinkuolie  Sarah  10196          1                1         0
# 3                Alagbe Trina  10088          1                1         0
# 4            Anderson  Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 577          Anderson  Carol   10069          0                2         0
# 578         Anderson  Linda    10002          0                0         0
# 579           Andreola  Colby  10194          0                0         0
# 580               Athwal  Sam  10062          0                4         1
# 581          Bachiochi  Linda  10114          0                0         0
#
# ...

# %%
#df3['DateofTermination'].

# %%
df3.isnull().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Gender                          0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             386
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %% [markdown]
# # use replace function for removing unwanted data and replacing if from
# # replace function (find,replace,regex)

# %%
# remove unwanted data from data set
# Replace function is used for removing unwanted data and replacing it from valid text or space
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               582 non-null    str
#  1   EmpID                       582 non-null    int64
#  2   MarriedID                   582 non-null    int64
#  3   MaritalStatusID             582 non-null    int64
#  4   GenderID                    582 non-null    int64
#  5   EmpStatusID                 582 non-null    int64
#  6   DeptID                      582 non-null    int64
#  7   PerfScoreID                 582 non-null    int64
#  8   FromDiversityJobFairID      582 non-null    int64
#  9   Salary                      582 non-null    str
#  10  Termd                       582 non-null    int64
#  11  PositionID                  582 non-null    int64
#  12  Position                    582 non-null    str
# ...

# %%
df3.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi  Wilson  K  10026          0                0         1
# 1  Ait Sidi  Karthikeyan     10084          1                1         1
# 2         Akinkuolie  Sarah  10196          1                1         0
# 3              Alagbe Trina  10088          1                1         0
# 4          Anderson  Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# 0            1       5            4                       0   rs.62,506.00
# 1            5       3            3                       0  rs.104,437.00
# 2            5       5            3                       0   rs.64,955.00
# 3            1       5            3                       0   rs.64,991.00
# 4            5       5            3                       0   rs.50,825.00
#
#    ...     ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
# replace(find,replace_value,regex=False) in default regex is True ,but if we want to change or replace then make false
# regex-->(,..@32$%+*)

df3['Employee_Name']= df3['Employee_Name'].str.replace(',',' ', regex = False)

# %%
df3.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi  Wilson  K  10026          0                0         1
# 1  Ait Sidi  Karthikeyan     10084          1                1         1
# 2         Akinkuolie  Sarah  10196          1                1         0
# 3              Alagbe Trina  10088          1                1         0
# 4          Anderson  Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# 0            1       5            4                       0   rs.62,506.00
# 1            5       3            3                       0  rs.104,437.00
# 2            5       5            3                       0   rs.64,955.00
# 3            1       5            3                       0   rs.64,991.00
# 4            5       5            3                       0   rs.50,825.00
#
#    ...     ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# remove unwanted white-space

# %%
# remove unwanted white-space
# categorical record
df3.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Gender', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='str')

# %%
# categorical
columns = ['Position', 'State', 'Gender', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino','RaceDesc',
           'TermReason','EmploymentStatus','Department','RecruitmentSource']

for col in columns:
    u_col = df3[col].unique()
    print(col)
    print("-"*50)
    print(f'{u_col}\n')
# Out:
# Position
# --------------------------------------------------
# <StringArray>
# [     'Production Technician I',                      'Sr. DBA',
#      'Production Technician II',            'Software Engineer',
#                    'IT Support',                 'Data Analyst',
#        'Database Administrator',         'Enterprise Architect',
#                'Sr. Accountant',           'Production Manager',
#                  'Accountant I',           'Area Sales Manager',
#  'Software Engineering Manager',                  'BI Director',
#        'Director of Operations',         'Sr. Network Engineer',
#                 'Sales Manager',                 'BI Developer',
#          'IT Manager - Support',             'Network Engineer',
#                   'IT Director',            'Director of Sales',
#      'Administrative Assistant',              'President & CEO',
#           'Senior BI Developer',      'Shared Services Manager',
# ...

# %%
#strip() --> which is used for removing extra spece
strip_columns =['Position','Gender','Department']
for st_col in strip_columns:
    df3[st_col] = df3[st_col].str.strip()

# %%
# df3['Position'].unique()
#df3['Gender'].unique()
df3['Department'].unique()
# Out:
# <StringArray>
# [          'Production',                'IT/IS', 'Software Engineering',
#         'Admin Offices',                'Sales',     'Executive Office']
# Length: 6, dtype: str

# %% [markdown]
# # Lable encoding

# %%
df3['HispanicLatino'] = (
    df3['HispanicLatino']
    .astype(str)          # convert to string
    .str.strip()          # remove spaces
    .str.lower()          # normalize case
    .map({'yes': 'Yes', 'no': 'No'})
)

# %%
df3['HispanicLatino'].unique() # reason behind to show nan
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
# hispanic latino
hl_data = {
    'No':'No',
    'Yes':'Yes',
    'no':'No',
    'yes':'Yes'
 }
df3['HispanicLatino'] = df3['HispanicLatino'].map(hl_data)

# %%
df3['HispanicLatino'].unique() # reason behind to show nan
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               582 non-null    str
#  1   EmpID                       582 non-null    int64
#  2   MarriedID                   582 non-null    int64
#  3   MaritalStatusID             582 non-null    int64
#  4   GenderID                    582 non-null    int64
#  5   EmpStatusID                 582 non-null    int64
#  6   DeptID                      582 non-null    int64
#  7   PerfScoreID                 582 non-null    int64
#  8   FromDiversityJobFairID      582 non-null    int64
#  9   Salary                      582 non-null    str
#  10  Termd                       582 non-null    int64
#  11  PositionID                  582 non-null    int64
#  12  Position                    582 non-null    str
# ...

# %%
mgr_mode = df3['ManagerID'].mode()[0]

# %%
df3['ManagerID'] = df3['ManagerID'].fillna(mgr_mode)

# %%
df3['ManagerID'] = df3['ManagerID'].astype(int)

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               582 non-null    str
#  1   EmpID                       582 non-null    int64
#  2   MarriedID                   582 non-null    int64
#  3   MaritalStatusID             582 non-null    int64
#  4   GenderID                    582 non-null    int64
#  5   EmpStatusID                 582 non-null    int64
#  6   DeptID                      582 non-null    int64
#  7   PerfScoreID                 582 non-null    int64
#  8   FromDiversityJobFairID      582 non-null    int64
#  9   Salary                      582 non-null    str
#  10  Termd                       582 non-null    int64
#  11  PositionID                  582 non-null    int64
#  12  Position                    582 non-null    str
# ...

# %%
# formate oprion in mutiple formate 

'''
---------------------
format(parameter)
----------------------
'%d.%m.%Y'-default
'%d-%M-%Y'  
'mixed'


datfirst = true (default =  false)
change formate -> 'Y-M-D'
'''
# Out:
# "\n---------------------\nformat(parameter)\n----------------------\n'%d.%m.%Y'-default\n'%d-%M-%Y'  \n'mixed'\n\n\ndatfirst = true (default =  false)\nchange formate -> 'Y-M-D'\n"

# %%
df3['DOB'] = pd.to_datetime(df3['DOB'])

# %%
df3['DOB']
# Out:
# 0     1983-07-10
# 1     1975-05-05
# 2     1988-09-19
# 3     1988-09-27
# 4     1989-09-08
#          ...
# 577   1989-09-08
# 578   1977-05-22
# 579   1979-05-24
# 580   1983-02-18
# 581   1970-02-11
# Name: DOB, Length: 582, dtype: datetime64[us]

# %%
df.isnull().sum()
# Out:
# EMPLOYEE_ID       0
# FIRST_NAME        0
# LAST_NAME         0
# EMAIL             0
# PHONE_NUMBER      0
# HIRE_DATE         0
# JOB_ID            0
# SALARY            0
# COMMISSION_PCT    0
# MANAGER_ID        0
# DEPARTMENT_ID     0
# dtype: int64

# %%
df['HIRE_DATE'] = pd.to_datetime(df['HIRE_DATE'],format ='mixed')

# %%
df['HIRE_DATE']
# Out:
# 0     2003-06-17
# 1     2005-09-21
# 2     2001-01-13
# 3     2006-01-03
# 4     2007-05-21
#          ...
# 106   2002-06-07
# 107   2002-06-07
# 108   2002-06-07
# 109   2002-06-07
# 110   2002-06-07
# Name: HIRE_DATE, Length: 111, dtype: datetime64[us]

# %%
# assignment about split function which is also one of the string function
# import re
#re.sub()
# explain about regular expression

# %% [markdown]
# # how we use split in this

# %%
text = "Data science is fun"
result = text.split()
print(result)
# Out:
# ['Data', 'science', 'is', 'fun']

# %%
pinkidata = "my name is pinki and i am learning data science now, but i also interested in machine learning"
result = pinkidata.split(" ", 3)
print(result)
# Out:
# ['my', 'name', 'is', 'pinki and i am learning data science now, but i also interested in machine learning']
